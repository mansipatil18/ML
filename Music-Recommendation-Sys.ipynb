# %%
import pandas as pd
import pandas as pd

# %%
df=pd.read_csv(r"ex.csv")
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba      8.8/10
# 1     BollywoodDanceRomantic                Luka Chuppi      9.0/10
# 2             BollywoodDance                  Gully Boy      9.7/10
# 3             BollywoodDance              Total Dhamaal      9.1/10
# 4          BollywoodRomantic                     Simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural      6.2/10
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai      7.2/10
# 2417          BollywoodDance                      Lamhe      7.5/10
# 2418          BollywoodDance          Shola Aur Shabnam      6.5/10
# 2419          BollywoodDance          Shola Aur Shabnam      6.6/10
#
# [2420 rows x 5 columns]

# %%
df.isnull().sum(0)
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (2391, 5)

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df
# Out:
# <ipython-input-10-7733f995defa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu  Mika Singh  Neha Kakkar
# 1                             Neha Kakkar  Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri  Shaan  Subhro Ganguly
# 4     Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar  Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba      8.8/10
# 1     BollywoodDanceRomantic                Luka Chuppi      9.0/10
# 2             BollywoodDance                  Gully Boy      9.7/10
# 3             BollywoodDance              Total Dhamaal      9.1/10
# 4          BollywoodRomantic                     Simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural      6.2/10
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai      7.2/10
# 2417          BollywoodDance                      Lamhe      7.5/10
# 2418          BollywoodDance          Shola Aur Shabnam      6.5/10
# 2419          BollywoodDance          Shola Aur Shabnam      6.6/10
#
# [2391 rows x 5 columns]

# %%
new_df=df[['Song-Name']]
new_df
# Out:
#                                Song-Name
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
# [2391 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %%
vectors=cv.fit_transform(new_df['Song-Name']).toarray()

# %%
vectors.shape
# Out:
# (2391, 2000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
new_df.rename(columns={'Song-Name': 'title'}, inplace=True)
# Out:
# <ipython-input-16-4c890d0f0d7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name': 'title'}, inplace=True)

# %%
def recommend (music):
  music_index=new_df [new_df['title']==music].index[0]
  distances=similarity[music_index]
  music_list=sorted(list(enumerate (distances)), reverse=True, key=lambda x:x[1]) [1:6]
  for i in music_list:
    print(new_df.iloc[i[0]].title)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity (vectors)

# %%
new_df.rename(columns={'Song-Name': 'title'}, inplace=True)
# Out:
# <ipython-input-19-4c890d0f0d7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name': 'title'}, inplace=True)

# %%
def recommend(music):
  music_index=new_df[new_df['title']==music].index[0]
  distances=similarity[music_index]
  music_list=sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]
  for i in music_list:
    print(new_df.iloc[i[0]].title)

# %%
recommend('Tere Bin')
# Out:
# Tere Bin
# Bin Tere
# Ab Tere Bin
# Tere Bin Nahi Laage
# Tere Liye

# %%
df.head(50)
# Out:
#                           Song-Name  \
# 0                       Aankh Marey
# 1                         Coca Cola
# 2                  Apna Time Aayega
# 3                            Mungda
# 4                          Tere Bin
# 5                         Gali Gali
# 6                     Chamma Chamma
# 7                   Mere Gully Mein
# 8                          Kamariya
# 9   Ek Ladki Ko Dekha Toh Aisa Laga
# 10                   Swag Se Swagat
# 11                  Poster Lagwa Do
# 12                      Daaru Wargi
# 13                           Dilbar
# 14                    Proper Patola
# 15                            Doori
# 16                 Dil Diyan Gallan
# 17                     Husn Parcham
# 18                  Bom Diggy Diggy
# 19                       Issaqbaazi
# 20                     Mere Naam Tu
# 21    High Rated Gabru – Nawabzaade
# 22                    Dekhte Dekhte
# 23                          Zingaat
# 24                         Tareefan
# 25            Mile Ho Tum (Reprise)
# 26                        Dil Chori
# 27                 Tere Naal Nachna
# 42                                           Dev Negi          BollywoodDance
# 43                                       Amit Trivedi     BollywoodDevotional
# 44                       Arijit Singh  Nikhita Gandhi       BollywoodRomantic
# 45                     Armaan Malik  Shashaa Tirupati          BollywoodDance
# 46        Navraj Hans  Neha Kakkar  Yo Yo Honey Singh          BollywoodDance
# 47                          Amit Mishra  Arijit Singh          BollywoodDance
# 48                                     Jubin Nautiyal       BollywoodRomantic
# 49                   Amar Arshi  Badshah  Neha Kakkar          BollywoodDance
#
#                         Album/Movie User-Rating
# 0                            Simmba      8.8/10
# 1                       Luka Chuppi      9.0/10
# 2                         Gully Boy      9.7/10
# 3                     Total Dhamaal      9.1/10
# 4                            Simmba      9.2/10
# 5                               KGF      9.1/10
# 6                     Fraud Saiyaan      9.2/10
# 7                         Gully Boy      9.5/10
# 8                            Mitron      9.2/10
# 9   Ek Ladki Ko Dekha Toh Aisa Laga      9.6/10
# 10                  Tiger Zinda Hai      8.8/10
# 11                      Luka Chuppi      8.4/10
# 12                      Cheat India      9.1/10
# 13                 Satyameva Jayate      9.2/10
# 14                  Namaste England      9.0/10
# 15                        Gully Boy      9.7/10
# 16                  Tiger Zinda Hai      9.1/10
# 17                             Zero      9.0/10
# 18           Sonu Ke Titu Ki Sweety      9.0/10
# 19                             Zero      9.1/10
# 20                             Zero      9.2/10
# 21                       Nawabzaade      9.2/10
# 22            Batti Gul Meter Chalu      9.5/10
# 23                           Dhadak      8.6/10
# 24                 Veere Di Wedding      9.1/10
# 25                            Fever      9.0/10
# 26           Sonu Ke Titu Ki Sweety      9.0/10
# 27                       Nawabzaade      9.2/10
# 28                           Genius      9.5/10
# 29                           Dhadak      9.4/10
# 30                           Race 3      8.7/10
# 31                        Loveratri      9.3/10
# 32  Ek Ladki Ko Dekha Toh Aisa Laga      9.3/10
# 33                 Satyameva Jayate      9.5/10
# 34                            Stree      9.1/10
# 35                       Badhaai Ho      9.0/10
# 36                  Namaste England      9.0/10
# 37                        Padmaavat      9.1/10
# 38                            Stree      8.4/10
# 39            Badrinath Ki Dulhania      8.4/10
# 40                          Machine      8.8/10
# 41                        Loveratri      9.2/10
# 42                        Kedarnath      9.2/10
# 43                        Kedarnath      9.6/10
# 44                        Kedarnath      9.6/10
# 45                                2      9.0/10
# 46           Sonu Ke Titu Ki Sweety      9.1/10
# 47                     Jagga Jasoos      8.5/10
# 48                      Cheat India      9.5/10
# 49                  Baar Baar Dekho      8.5/10

# %%
import pickle
pickle.dump(new_df,open('musicrec.pkl','wb'))

# %%
pickle.dump(new_df,open('similarities.pkl','wb'))

# %%
recommend ('Tere Bin')
# Out:
# Tere Bin
# Bin Tere
# Ab Tere Bin
# Tere Bin Nahi Laage
# Tere Liye

# %%
recommend ('Coca Cola')
# Out:
# Aankh Marey
# Apna Time Aayega
# Mungda
# Tere Bin
# Gali Gali

# %%
recommend ('Tu Hi Re')
# Out:
# Tu Hi Haqeeqat
# Tu Hi Khwahish
# Meri Duniya Tu Hi Re
# Tu Hi Tu
# Ik Tu Hi Tu Hi

# %%
recommend ('Dholida')
# Out:
# Aankh Marey
# Coca Cola
# Apna Time Aayega
# Mungda
# Tere Bin
